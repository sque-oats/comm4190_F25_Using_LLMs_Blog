# %% [raw]
# ---
# title: "First Test"
# description: "Figuring out how to blog"
# author: "Suya"
# date: "9/3/2025"
# categories:
#   - Getting Started
# ---

# %% [markdown]
# ![YinYangCats.jpg](attachment:cb898cfc-2021-4aa3-8aca-2550c0b47f4a.jpg)

# %% [markdown]
# I'm testing out uploading a post here. I also tested uploading an image. No AI was used in the creation of this post.

# %% [markdown]
# Hi! My name is Suya and I am a senior studying bionengineering. I've seen how much AI and its usage has evolved over the past few years, especially in education, and I'm excited to better understand the machinations behind this evolution.
# Fun fact: my favorite animal is the cat, hence the picture (credit: Pinterest)!
