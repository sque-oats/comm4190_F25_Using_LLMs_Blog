# %% [raw]
# ---
# title: "Can Gemini 3 Pro generate educational lesson plans?"
# description: "One topic across multiple education levels. How will LLMs tailor these lesson plans differently?"
# author: "Suya"
# date: "12/13/2025"
# categories:
#   - LLMs
#   - The AI Con
#   - Education
# ---

# %% [markdown]
# ![Loafing cat photoshopped in front of chalk board](teachercat.jpg)

# %% [markdown]
# # Context

# %% [markdown]
# *The AI Con* discusses how they view it as worrisome that teachers are using AI to develop lesson plans and homework assignments. A documentary I watched on AI integration into education in China instead frames it as something extremely helpful. I want to see for myself what an LLM is capable of in this space.

# %% [markdown]
# # Experiments

# %% [markdown]
# Every experiment will be of developing a lesson plan of the same topic, using the same LLM Gemini 3 Pro. The only thing that will change is the education level I say the lesson plan is intended for -> elementary schooler, high schooler, and PhD (unspecified in what) student.

# %% [markdown]
# The topic is: **Gilded Age Period in US history, with emphasis on the Presidents at that time**.

# %% [markdown]
# Overall prompt:
# > Please develop a lesson plan for me. I am a teacher/professor for a class on US history, and we are starting the Gilded Age unit. I am teaching to a class of _*education level*_. What lesson plan should I follow during my first week in this unit? We have class for 1.5 hours on Mondays, Wednesdays, and Fridays. Please include topics I should cover as well as assignments/quizzes/exams. Format this lesson plan in concise bullet points.

# %% [markdown]
# ## 3rd grader

# %% [markdown]
# **AI Response:** <br>
#
# Here is a tailored lesson plan for the first day of a Gilded Age unit, adapted specifically for 3rd graders (approx. 8–9 years old). <br>
#
# **Teacher's Note:** Since the Gilded Age involves complex economics and political corruption, this plan focuses on tangible concepts appropriate for this age group: Invention, Industrialization (Big Machines), and the contrast between Rich and Poor. <br><br>
#
# ***Unit Theme: "Glitter on the Outside, Rusty on the Inside"*** <br>
# **Monday: What Does "Gilded" Mean?** <br>
# **Goal:** Students will understand that the "Gilded Age" was a time of great wealth for some, but hardship for others. <br><br>
#
# *Time Allocation (1.5 Hours):* <br>
#
# 15 mins: Hook Activity - The Golden Rock. Show the class a rock painted gold (or a gold-foil wrapped item). Ask if it is real gold. Peel/chip it to reveal the ordinary rock underneath. Explain the term "Gilded." <br>
#
# 30 mins: Lecture/Story: Show pictures of "The Vanderbilts" and their mansions. Contrast with pictures of crowded city tenements. <br>
#
# 30 mins: Activity - "Rich & Poor" T-Chart. As a class, sort images or descriptive cards into two columns on the board: "Life in a Mansion" vs. "Life in a Tenement." <br>
#
# 15 mins: Wrap-up/Journal: Students draw one thing a rich person might own and one thing a poor person might struggle with. <br><br><br>
#
# **Wednesday: The Age of Invention**<br>
# **Goal:** Students will identify key inventions of the era (Lightbulb, Telephone, Skyscrapers) and how they changed life. <br><br>
#
# *Time Allocation (1.5 Hours):* <br>
#
# 15 mins: Review: Quick recall of Monday's "Gilded" concept.<br>
#
# 30 mins: Presentation: Introduce Thomas Edison (Lightbulb), Alexander Graham Bell (Telephone), and the rise of Steel (Skyscrapers). Discuss life before these existed (candles, letters, small wooden buildings).<br>
#
# 30 mins: Activity - "Then and Now" Sorting Game. Students work in pairs to match "Gilded Age" items (candle, horse carriage) to their modern equivalents or the new inventions of that time (lightbulb, steam train).<br>
#
# 15 mins: Creative Assignment: "My Invention." Students have free time to draw a blueprint of a machine they would invent to make life easier. <br><br>
#
# **Friday: Factories & The Assembly Line** <br>
# **Goal:** Students will experience how goods were made in factories and understand the concept of mass production. <br><br>
#
# *Time Allocation (1.5 Hours):* <br>
#
# 15 mins: Intro: Discuss how clothes/toys were made by hand previously vs. by machines in the Gilded Age.<br>
#
# 45 mins: Simulation - The Assembly Line.<br>
#
# Round 1 (Craftsman): Each student tries to make a complete paper chain (5 links, colored, stapled) alone. Time them.<br>
#
# Round 2 (Factory): Assign specific roles (The Cutter, The Colorer, The Stapler). Time them again to see how much faster it is, but discuss how boring the job feels (repetitive motion).<br>
#
# 20 mins: Debrief: Discuss which method was faster vs. which was more fun. Relate this to how factory workers felt.<br>
#
# 10 mins: Weekly Quiz: Simple check for understanding.<br><br>
#
# **Assessments & Grading** <br>
# *Formative (Ongoing):* <br>
#
# Monday Journal Entry: Check for understanding of the wealth gap visual.<br>
#
# Wednesday Sorting Game: participation grade.<br><br>
#
# *Summative (End of Week):* <br>
#
# Friday Short Quiz (5 Questions):<br>
#
# What does the word "Gilded" mean? (A: Shiny outside, plain inside)<br>
#
# Name one invention we discussed.<br>
#
# True or False: Everyone was rich during the Gilded Age.<br>
#
# Circle the picture of the Telephone.<br>
#
# Did assembly lines make building things faster or slower?
# <br>
# Would you like me to generate the printable handouts for the "Then and Now" sorting game or the "Assembly Line" simulation instructions?<br>

# %% [markdown]
# ## High School Junior

# %% [markdown]
# **AI Response:** <br>
# Here is a comprehensive lesson plan for the first week of a Gilded Age unit, designed for 11th Grade US History. <br><br>
#
# ***Unit Essential Question: Was the Gilded Age a period of golden progress or covered-up corruption?*** <br>
#
# **Monday: The Titans of Industry & The "Gilded" Metaphor** <br>
# **Topic:** Introduction to the era, Mark Twain’s definition, and the rise of Big Business. <br>
#
# *Time Allocation (90 Minutes):* <br>
#
# 15 mins: Hook/Lecture: Define "Gilded" (shiny on the outside, rotting underneath). Introduce Mark Twain’s critique. <br>
#
# 30 mins: Deep Dive: The rise of Railroads, Steel (Carnegie), and Oil (Rockefeller). Discuss Vertical vs. Horizontal Integration. <br>
# ![gemini screenshot](attachment:ac966760-43a5-4095-9126-bba433f523ba.png) <br> <br>
#
# **Wednesday: Urbanization, Immigration & Social Ideologies** <br>
# **Topic:** The shift from rural to urban, "New Immigration," and the philosophies justifying wealth. <br>
#
# *Time Allocation (90 Minutes):* <br>
#
# 20 mins: Lecture: The "New Immigrant" (Southern/Eastern Europe) vs. Old Immigrant. Push/Pull factors. <br>
#
# 25 mins: Primary Source Lab - "How the Other Half Lives": <br>
#
# Analyze photos by Jacob Riis. Discuss the architecture of the "Dumbbell Tenement." <br>
#
# 25 mins: Concept Comparison: <br>
#
# Social Darwinism: "Survival of the fittest" applied to economics. <br>
#
# The Gospel of Wealth: Carnegie’s argument that the wealthy have a duty to improve society. <br>
#
# 20 mins: Political Machines: Brief intro to Boss Tweed and Tammany Hall using Thomas Nast cartoons. <br> <br>
#
# **Friday: The Labor Movement & Violent Conflict** <br>
# **Topic:** Working conditions, the rise of Unions (AFL vs. Knights of Labor), and major strikes. <br>
#
# *Time Allocation (90 Minutes):* <br>
#
# 20 mins: Simulation: "The Factory." Turn off lights, play loud industrial noise, and have students perform a repetitive writing task to simulate conditions (monotony, danger). <br>
#
# 30 mins: Lecture/Discussion: The formation of Unions. Compare the Knights of Labor (inclusive/radical) vs. American Federation of Labor (exclusive/skilled). <br>
#
# 30 mins: Case Studies - The Great Strikes: <br>
#
# Great Railroad Strike of 1877. <br>
#
# Haymarket Affair (Anarchism fears). <br>
#
# Homestead Strike (Pinkertons vs. Steelworkers). <br>
#
# 10 mins: Weekly Quiz: Assessing key terms and concepts from the week. <br> <br>
#
# **Assignments & Assessments** <br>
# *Formative (In-Class):* <br>
#
# Monday: "Robber Baron" Thesis Statement. <br>
#
# Wednesday: Jacob Riis Photo Analysis Worksheet. <br> <br>
#
# *Summative (End of Week):* <br>
#
# Friday Quiz (Multiple Choice & Short Answer): <br>
#
# Sample Q: Explain the difference between Vertical and Horizontal Integration. <br>
#
# Sample Q: Analyze the provided political cartoon (Thomas Nast) and explain its message regarding political machines. <br>
#
# Weekend Homework - DBQ Prep: Read documents A-D regarding the Pullman Strike (to be discussed next Monday) and outline an argument: Did the government justifiably intervene in the Pullman Strike? <br>
#
# Would you like me to generate a specific rubric for the "Robber Barons vs. Captains of Industry" debate or specific questions for the Jacob Riis photo analysis? <br>

# %% [markdown]
# ## 2nd Year PhD Student

# %% [markdown]
# Here is a lesson plan tailored for 2nd-year PhD students.  <br>
#
# **Instructor's Note:** At this level, the focus shifts entirely from content mastery ("what happened") to historiography, methodology, and theoretical frameworks. The objective is to critique how the "Gilded Age" has been constructed by historians and to situate American industrialization within global capitalism, legal history, and critical race theory.  <br> <br>
#
# ***Unit Theme: "The Search for Order" — Historiography & Political Economy*** <br>
# **Monday: Deconstructing the "Gilded" Paradigm** <br>
# **Goal:** Critique the periodization of the "Gilded Age" and analyze the evolution of historical interpretation from the Progressives to the "New History of Capitalism." <br>
#
# *Time Allocation (1.5 Hours):* <br>
#
# 30 mins: Seminar Discussion - The Nomenclature of an Era. <br>
#
# Discussion: Is "Gilded Age" (Twain/Warner) a useful analytical category, or does it obscure the continuities of the "Long Nineteenth Century"? <br>
#
# Contrast with the "Victorian" or "Reconstruction" frameworks. <br>
#
# 40 mins: Historiographical Arc Analysis. <br>
#
# The Progressives: Beard & Parrington (Economic determinism/Robber Barons). <br>
#
# The Consensus School: Hofstadter (Status anxiety/Psychological roots). <br>
#
# The Organizational Synthesis: Robert Wiebe & Alfred Chandler (The rise of bureaucracy and the managerial class). <br>
#
# 20 mins: Synthesis: How does Richard White’s The Republic for Which It Stands challenge the "Search for Order" thesis? <br> <br>
#
# **Wednesday: The Myth of Laissez-Faire — Law & The State** <br>
# **Goal:** Challenge the popular narrative of a "weak state" by examining the active role of the judiciary and federal government in constructing corporate power. <br>
#
# *Time Allocation (1.5 Hours):* <br>
#
# 20 mins: Theoretical Framework: Intro to Polanyi’s The Great Transformation. Discuss the concept that "Laissez-faire was planned." <br>
#
# 40 mins: Case Law Deep Dive: <br>
#
# Santa Clara County v. Southern Pacific Railroad (1886): The construction of Corporate Personhood. <br>
#
# Lochner v. New York (1905) and Substantive Due Process. <br>
#
# 30 mins: Methodological Workshop: "Reading Against the Grain." <br>
#
# Analyze a standard corporate annual report from 1890. Discuss how to use business archives to find evidence of state collusion, rather than just profit/loss data. <br> <br>
#
# **Friday: Race, Labor, and the Transnational Turn**
# **Goal:** Re-examine the labor question through the lens of racial capitalism and place the U.S. Gilded Age in a global context (The Great Deflation). <br>
#
# *Time Allocation (1.5 Hours):* <br>
#
# 30 mins: Discussion - The "Wages of Whiteness." <br>
#
# Analyze W.E.B. Du Bois’s Black Reconstruction (specifically the chapters on the post-1877 labor split). <br>
#
# Discuss the Chinese Exclusion Act (1882) as a labor tool, not just immigration policy. <br>
#
# 30 mins: Global Context:  <br>
#
# Compare the U.S. "Long Depression" (1873-1896) with simultaneous crises in Great Britain and Germany.  <br>
#
# Discussion: How did the "closing of the frontier" link to the rise of American Imperialism?  <br>
#
# 30 mins: Prospectus Review: Round-table critique of student research ideas. Students briefly pitch how they might use Gilded Age archives for their dissertation topics. <br> <br>
#
# **Assignments & Assessments** <br>
# *Weekly Deliverable (Due Friday 9 AM):* <br>
#
# Historiographical Précis (1,000 words): Compare and contrast Robert Wiebe’s The Search for Order with a modern monograph (e.g., by Richard White or Sven Beckert). Argue which framework offers a more compelling explanation for the rise of the corporation. <br> <br>
#
# *Seminar Preparation:* <br>
#
# Students must prepare 3 discussion questions based on the week's reading (Reading List: The Republic for Which It Stands, Black Reconstruction, and Santa Clara County court opinion). <br> <br>
#
# *Semester Project Lead-in:* <br>
#
# Archive Identification: Identify one physical or digital archive (e.g., The Library of Congress, HathiTrust, local historical society) containing unexamined Gilded Age legal or corporate records relevant to their dissertation interest. <br>
#
# Would you like me to generate a specific reading list of journal articles for the "Transnational Turn" discussion or a guide on "How to Read Legal Briefs for Historians"? <br>

# %% [markdown]
# # Takeaways

# %% [markdown]
# With the 3rd grader lesson plan, the lesson plan honestly seems pretty strong to me...until it gets to the quiz. I think just circling a picture of a telephone isn't exactly teaching students about the Gilded Age.

# %% [markdown]
# The lesson plan for high school juniors is the only one that includes a graphic of a sample homework or note sheet. Honestly, the amount of assignments is much more in quantity and in level than I experienced from my high school, but who knows, maybe this works for some people.

# %% [markdown]
# The PhD lesson plan kind of assumes that the students are studying within this field for their degree, which I find interesting but not super surprising. It's also interesting how there are almost no quizzes exams in this plan, instead having projects and class discussions as the basis.

# %% [markdown]
# Ultimately, I feel like the lesson plans Gemini generated are not bad, but would definitely require additional tailoring and editing from educators. As well, as someone who is not an educator maybe I don't have the best perspective on what makes a good lesson plan or not. But these generated ones are more detailed than I expected. Still, I wouldn't be happy if my teacher used one straight from an AI. Every class is different, every school is different, and I don't think these would always work everywhere.
